# %% [markdown]
# <a href="https://colab.research.google.com/github/MukunthanPeriyasamy/Deep_Learning_Projects/blob/main/Spam_Mail_Prediction_Using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf

# %%
import zipfile

zipfiles = zipfile.ZipFile('spam_ham_dataset.csv.zip')
zipfiles.extractall()

# %%
# Reading CSV file and Creating DataFrame

dataset = pd.read_csv('spam_ham_dataset.csv')
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
df.drop(columns='Unnamed: 0',inplace=True,axis=1)

# %%
df.head()
# Out:
#   label                                               text  label_num
# 0   ham  Subject: enron methanol ; meter # : 988291\r\n...          0
# 1   ham  Subject: hpl nom for january 9 , 2001\r\n( see...          0
# 2   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...          0
# 3  spam  Subject: photoshop , windows , office . cheap ...          1
# 4   ham  Subject: re : indian springs\r\nthis deal is t...          0

# %% [markdown]
# 1. Ham --> 0
# 2. Spam --> 1

# %% [markdown]
# In the dataset we are already having the label as number (i.e 0 and 1) for ham and spam mail. So we can delete the label column.

# %%
df.drop(columns='label',inplace=True,axis=1)

# %%
df.head()
# Out:
#                                                 text  label_num
# 0  Subject: enron methanol ; meter # : 988291\r\n...          0
# 1  Subject: hpl nom for january 9 , 2001\r\n( see...          0
# 2  Subject: neon retreat\r\nho ho ho , we ' re ar...          0
# 3  Subject: photoshop , windows , office . cheap ...          1
# 4  Subject: re : indian springs\r\nthis deal is t...          0

# %% [markdown]
# **Note** 🔑: changing the columns name
# > text--> mail and
#
# > label_num -- > label

# %%
df.rename(columns={'text':'mail','label_num':'label'},inplace=True)
df.head()
# Out:
#                                                 mail  label
# 0  Subject: enron methanol ; meter # : 988291\r\n...      0
# 1  Subject: hpl nom for january 9 , 2001\r\n( see...      0
# 2  Subject: neon retreat\r\nho ho ho , we ' re ar...      0
# 3  Subject: photoshop , windows , office . cheap ...      1
# 4  Subject: re : indian springs\r\nthis deal is t...      0

# %% [markdown]
# **Important Peocess**⚒️ :
#
#   Converting the text mail into vectors using CountVectorizer

# %%
x = df.iloc[:,0].values
y = df.iloc[:,-1].values

# %%
# Splitting the dataset into training and testing dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Converting the text data into feature vector
from sklearn.feature_extraction.text import TfidfVectorizer
tf_idf = TfidfVectorizer(min_df=1,stop_words='english',lowercase=True)
x_train = tf_idf.fit_transform(x_train)
x_test = tf_idf.transform(x_test)

# %% [markdown]
# **Building the Model** 🏗️🏗️🏗️

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(5,activation='relu'),
    tf.keras.layers.Dense(5,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy']
              )

model.fit(x_train,y_train,batch_size=32,epochs=10)
# Out:
# Epoch 1/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7139 - loss: 0.6373
# Epoch 2/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7126 - loss: 0.3768
# Epoch 3/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7633 - loss: 0.2550
# Epoch 4/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9900 - loss: 0.2192
# Epoch 5/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9971 - loss: 0.1775
# Epoch 6/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9982 - loss: 0.1559
# Epoch 7/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9998 - loss: 0.1390
# Epoch 8/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9992 - loss: 0.1305
# Epoch 9/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9999 - loss: 0.1175
# Epoch 10/10
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9999 - loss: 0.1139

# %% [markdown]
# **Prediction System** 🖥️🖥️

# %%
new_mail = ["Subject: re : final notice # 7 v 8477 hi again , i sent you an email last week and need to confirm everything now . please read info below and let me know if you have any questions . we are accepting your mo rtgage application . if you have poor cr . edit , it is ok . you can get a $ 200 , 000 loa n for $ 650 / month payment . appr oval process will take 1 minute . just visit the link below and fill short form . http : / / gffefv . net / azwml sincerely , manager : geoffrey winston heritage financing	"]

new_mail = tf_idf.transform(new_mail)

predict = model.predict(new_mail)

final_prediction = predict[0][0].round(1)

print(final_prediction)
if final_prediction > 0.5:
  print("Spam Mail")
else:
  print("Ham Mail")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 0.7
# Spam Mail
